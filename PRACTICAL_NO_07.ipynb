# %% [markdown]
# <a href="https://colab.research.google.com/github/aryandakhare/Basic-Webpage-HTML-CSS-JS-/blob/main/PRACTICAL_NO_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXPERIMENT NO: 07,
# NAME: Aryan Gajanan Dakhare,
# BT ID: BT230009DS,
# SUBJECT: AI/ML

# %%
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap.umap_ as umap
import matplotlib.pyplot as plt
# Load data
digits = load_digits()
X = digits.data
y = digits.target
# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
# t-SNE
tsne = TSNE(n_components=2, perplexity=30)
X_tsne = tsne.fit_transform(X)
# UMAP
reducer = umap.UMAP(n_components=2)
X_umap = reducer.fit_transform(X)
# Plot
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, data, title in zip(axes, [X_pca, X_tsne, X_umap], ["PCA",
"t-SNE", "UMAP"]):
    scatter = ax.scatter(data[:, 0], data[:, 1], c=y, cmap='Spectral',
    s=10)

    ax.set_title(title)
plt.show()
